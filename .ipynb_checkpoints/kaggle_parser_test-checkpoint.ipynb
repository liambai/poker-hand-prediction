# %%
import sqlite3

conn = sqlite3.connect('poker.db')
c = conn.cursor()

# %%
lines = open("kaggle-data/kaggle_file1.txt" ,"r").readlines()
games = [[]]
for line in lines:
    games[-1].append(line)
    if line == '\n':
        games.append([])

# %%
for game in games:
    game_id = game[1].split(' ')[2]
    stakes = game[1].split(' ')[3]
    big_blind = stakes.split("/")[1]
    for line in game:
        words = line.split(" ")
        
        #get info about the 5 cards on the board
        if words[0] == "Board:":
            cards = [None]*5
            cards_info = words[1:]
            for i in range(len(cards_info)):
                cards[i] = cards_info[i].strip("[]")
    
    c.execute('''INSERT INTO Games VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', \
              (game_id, big_blind, cards[0], cards[1], cards[2], \
               cards[3], cards[4], None, None, None, None))
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-60-b7768a1f80f5> in <module>
#      15     c.execute('''INSERT INTO Games VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', \
#      16               (game_id, big_blind, cards[0], cards[1], cards[2], \
# ---> 17                cards[3], cards[4], None, None, None, None))
#      18     conn.commit()
#
# OperationalError: table Games has 7 columns but 11 values were supplied

# %%
for game in games:
    game_id = game[1].split(' ')[2]
